# %%
from pandas import DataFrame, read_csv 
import matplotlib.pyplot as plt
import pandas as pd
import sys
import matplotlib

# %matplotlib inline

# %%
print('Python Version', sys.version)
print('Pandas Version', pd.__version__)
print('matplotlib Version', matplotlib.__version__)
# Out:
# Python Version 3.5.1 |Anaconda custom (64-bit)| (default, Feb 16 2016, 09:49:46) [MSC v.1900 64 bit (AMD64)]
# Pandas Version 0.18.0
# matplotlib Version 1.5.1

# %%
names = ['Rittick', 'Shivam', 'Abhishek', 'Harshit', 'Jingtian']
births = [968, 155, 77, 578, 973]

# %%
zip?

# %%
BabyDataSet = list(zip(names, births))

# %%
BabyDataSet
# Out:
# [('Rittick', 968),
#  ('Shivam', 155),
#  ('Abhishek', 77),
#  ('Harshit', 578),
#  ('Jingtian', 973)]

# %%
df = pd.DataFrame(data=BabyDataSet, columns=['Names', 'Births'])

# %%
df
# Out:
#       Names  Births
# 0   Rittick     968
# 1    Shivam     155
# 2  Abhishek      77
# 3   Harshit     578
# 4  Jingtian     973

# %%
df.to_csv?

# %%
df.to_csv('births1880.csv', index=False, header=False)

# %%
read_csv?

# %%
df = pd.read_csv('births1880.csv')

# %%
df
# Out:
#     Rittick  968
# 0    Shivam  155
# 1  Abhishek   77
# 2   Harshit  578
# 3  Jingtian  973

# %%
df = pd.read_csv('births1880.csv', header=None)

# %%
df
# Out:
#           0    1
# 0   Rittick  968
# 1    Shivam  155
# 2  Abhishek   77
# 3   Harshit  578
# 4  Jingtian  973

# %%
df = pd.read_csv('births1880.csv', names=['Name', 'Births'])

# %%
df
# Out:
#        Name  Births
# 0   Rittick     968
# 1    Shivam     155
# 2  Abhishek      77
# 3   Harshit     578
# 4  Jingtian     973

# %%
import os

# %%
os.remove('births1880.csv')

# %%
df.dtypes
# Out:
# Name      object
# Births     int64
# dtype: object

# %%
df.Births.dtype
# Out:
# dtype('int64')

# %%
Sorted = df.sort_values(['Births'], ascending=False)

# %%
Sorted
# Out:
#        Name  Births
# 4  Jingtian     973
# 0   Rittick     968
# 3   Harshit     578
# 1    Shivam     155
# 2  Abhishek      77

# %%
Sorted.head(1)
# Out:
#        Name  Births
# 4  Jingtian     973

# %%
df.Births.max
# Out:
# <bound method _make_stat_function.<locals>.stat_func of 0    968
# 1    155
# 2     77
# 3    578
# 4    973
# Name: Births, dtype: int64>

# %%
df['Births'].max()
# Out:
# 973

# %%
df['Births'].plot()

# %%
MaxValue = df['Births'].max()

# %%
MaxName = df['Name'][df['Births'] == df['Births'].max()].values

# %%
MaxName
# Out:
# array(['Jingtian'], dtype=object)

# %%
Text = MaxName + '-' + str(MaxValue)

# %%
Text
# Out:
# array(['Jingtian-973'], dtype=object)

# %%
plt.annotate(Text, xy=(1, MaxValue), xytext=(8, 0), 
                 xycoords=('axes fraction', 'data'), textcoords='offset points')

# %%
print('The Most Popular Name')
# Out:
# The Most Popular Name

# %%
df[df['Births']==df['Births'].max()]
# Out:
#        Name  Births
# 4  Jingtian     973
